# %%
import pickle
import gzip

# Reading compressed pkl file
with gzip.open('your_file.pkl.gz', 'rb') as f:
    data = pickle.load(f)

# Saving as compressed pkl file
with gzip.open('your_file.pkl.gz', 'wb') as f:
    pickle.dump(your_data, f)
